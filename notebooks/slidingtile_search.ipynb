# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
import numpy as np

array_initial= np.array([
    [None, 1, 2],
    [3, 4, 5],
    [6, 7, 8]
])

array_final = np.array([
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, None]
])

# %%
from metaheuristics import *

# %%
state_initial = State.from_array(array_initial)
state_final = State.from_array(array_final)

# %%
problem = Problem(state_initial=state_initial, 
                  state_final=state_final)

# %%
actions = problem.actions(state_initial)

# %%
action = next(actions)
result = problem.result(state_initial, action)

# %%
node = best_first_search(problem)

# %%
print(node.parent.state)
# Out:
# State(grid=((1, 2, 3), (4, 5, None), (7, 8, 6)))
