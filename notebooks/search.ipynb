# %% [markdown]
# # Atividade Prática
#
# **Módulo**: Metaheurísticas Bioinspiradas e Tomada de Decisão Inteligente
#
# **Atividade**: Atividade 1 - Busca e Otimização
#
# **Professor**: Diego Pinheiro, PhD

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
from metaheuristics import *

# %% [markdown]
# ## Sliding Tile Search

# %%
initial_state_grid = np.array([
    [None, 1,  3],
    [4, 2, 6],
    [7, 5, 8]
])

initial_state = SlidingTileState(
    board=grid_to_tuple(initial_state_grid)
)

print(initial_state)
# Out:
# SlidingTileState(board=(0, 1, 3, 4, 2, 6, 7, 5, 8))

# %%
initial_node = Node(state=initial_state,parent=None,action=None, path_cost=0)
problem = Problem(initial_state=initial_node)
node = best_first_search(problem)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 initial_node = Node(state=initial_state,parent=None,action=None, path_cost=0)
#       2 problem = Problem(initial_state=initial_node)
# ----> 3 node = best_first_search(problem)
#
# File /workspaces/metaheuristics-code/notebooks/../metaheuristics/src/search/slidingtile_search.py:116, in best_first_search(problem)
#     114 if problem.is_goal(node.state):
#     115   return node
# --> 116 for child in expand(problem, node):
#     117   s = child.state
#     118   if s not in reached or child.path_cost < reached[s].path_cost:
#
# File /workspaces/metaheuristics-code/notebooks/../metaheuristics/src/search/slidingtile_search.py:100, in expand(problem, node)
#      98 def expand(problem: Problem, node: Node):
#      99   s = node.state
# --> 100   for action in problem.actions(s):
# ...

# %%
print(node.path_cost)
# Out:
# 4

# %%
print(node)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 None]]
#
# [[1 2 3]
#  [4 5 6]
#  [7 None 8]]
#
# [[1 2 3]
#  [4 None 6]
#  [7 5 8]]
#
# [[1 None 3]
#  [4 2 6]
#  [7 5 8]]
#
# [[None 1 3]
#  [4 2 6]
#  [7 5 8]]
#
# None

# %%
print(node.state)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 None]]

# %%
print(node.parent)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 None 8]]
#
# [[1 2 3]
#  [4 None 6]
#  [7 5 8]]
#
# [[1 None 3]
#  [4 2 6]
#  [7 5 8]]
#
# [[None 1 3]
#  [4 2 6]
#  [7 5 8]]
#
# None

# %%
print(node.parent.state)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 None 8]]
